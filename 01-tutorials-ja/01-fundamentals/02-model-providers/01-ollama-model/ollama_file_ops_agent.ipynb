# %% [markdown]
# # Strands AgentsとOllamaモデルでローカルエージェントを構築する
#
# このノートブックでは、Strands AgentとOllamaを使用してパーソナルエージェントを作成する方法を示します。エージェントは、ファイル操作、ウェブ検索、システムコマンドなどのさまざまなローカルタスクを実行できます。
#
# ## Ollamaとは？
#
# [Ollama](https://ollama.com/) は、オープンソースのフレームワークで、マシン上で大規模言語モデル（LLMs）をローカルに実行できます。これらのモデルと対話するためのシンプルなAPIを提供し、データを外部サービスに送信したくないプライバシー重視のアプリケーションに理想的です。
#
# Ollamaの主な利点：
# - **Privacy**: すべての処理がマシン上でローカルに行われる
# - **No API costs**: 好きなだけ無料で使用可能
# - **Offline capability**: インターネット接続なしで動作
# - **Customization**: 特定の用途に合わせて微調整可能
#
# ## Agent Details
#
# <div style="float: left; margin-right: 20px;">
#
# |Feature             |Description                                        |
# |--------------------|---------------------------------------------------|
# |Feature used        |Ollama Model - ファイル操作エージェントを作成するため   |
# |Agent Structure     |Single agent architecture                          |
#
# </div>

# %% [markdown]
# ### Agent Architecture
#
# <div style="text-align:center">
#     <img src="images/architecture.png" width="65%" />
# </div>

# %%
# !pip install -r requirements.txt

# %% [markdown]
# ## Setup and Installation
#
# このノートブックを実行する前に、以下のものを用意してください：
#
# 1. Ollamaをインストール: [https://ollama.com/download](https://ollama.com/download) の指示に従ってください
# 2. Ollamaサーバーを起動: `ollama serve`
# 3. Ollamaでモデルをダウンロード: `ollama pull llama3.2:1b`
#
# 詳細な指示については、[documentation](https://cuddly-sniffle-lrmk2y7.pages.github.io/0.1.x/user-guide/concepts/model-providers/ollama/) を参照してください。
#
# このノートブックでは、SageMaker Studioとの互換性のためにLinuxディストリビューション用のOllamaをダウンロードします。これは、Workshop StudioでのAWSリードワークショップ中のコード実行のために行われます。このコードをローカルで実行している場合は、現在の環境にOllamaをダウンロードするようにステップを調整してください。

# %%
# this will work on linux computers
# !curl -fsSL https://ollama.com/install.sh | sh

# %%
import subprocess
subprocess.Popen(['ollama', 'serve'])

# %%
# !ollama pull llama3.2:1b

# %%
# Import necessary libraries
import os

import requests

# Import strands components
from strands import Agent, tool
from strands.models.ollama import OllamaModel

# %%
# Check if Ollama is running:
try:
    response = requests.get("http://localhost:11434/api/tags")
    print("✅ Ollama is running. Available models:")
    for model in response.json().get("models", []):
        print(f"- {model['name']}")
except requests.exceptions.ConnectionError:
    print("❌ Ollama is not running. Please start Ollama before proceeding.")

# %% [markdown]
# ## カスタムツールの定義
#
# ツールは、エージェントが環境と対話するために使用する関数です。以下では、パーソナルエージェントに役立ついくつかのツールを定義します。

# %%
# File Operation Tools


@tool
def file_read(file_path: str) -> str:
    """Read a file and return its content.

    Args:
        file_path (str): Path to the file to read

    Returns:
        str: Content of the file

    Raises:
        FileNotFoundError: If the file doesn't exist
    """
    try:
        with open(file_path, "r") as file:
            return file.read()
    except FileNotFoundError:
        return f"Error: File '{file_path}' not found."
    except Exception as e:
        return f"Error reading file: {str(e)}"


@tool
def file_write(file_path: str, content: str) -> str:
    """Write content to a file.

    Args:
        file_path (str): The path to the file
        content (str): The content to write to the file

    Returns:
        str: A message indicating success or failure
    """
    try:
        # Create directory if it doesn't exist
        os.makedirs(os.path.dirname(os.path.abspath(file_path)), exist_ok=True)

        with open(file_path, "w") as file:
            file.write(content)
        return f"File '{file_path}' written successfully."
    except Exception as e:
        return f"Error writing to file: {str(e)}"


@tool
def list_directory(directory_path: str = ".") -> str:
    """List files and directories in the specified path.

    Args:
        directory_path (str): Path to the directory to list

    Returns:
        str: A formatted string listing all files and directories
    """
    try:
        items = os.listdir(directory_path)
        files = []
        directories = []

        for item in items:
            full_path = os.path.join(directory_path, item)
            if os.path.isdir(full_path):
                directories.append(f"Folder: {item}/")
            else:
                files.append(f"File: {item}")

        result = f"Contents of {os.path.abspath(directory_path)}:\n"
        result += (
            "\nDirectories:\n" + "\n".join(sorted(directories))
            if directories
            else "\nNo directories found."
        )
        result += (
            "\n\nFiles:\n" + "\n".join(sorted(files)) if files else "\nNo files found."
        )

        return result
    except Exception as e:
        return f"Error listing directory: {str(e)}"

# %% [markdown]
# ## Ollamaを活用したエージェントの作成
#
# 次に、上記で定義したツールを使用してOllamaモデルでエージェントを作成します。
#
# 注: `execute_commands`、`search_files` などのより多くのツールを追加できます。

# %%
# Define a comprehensive system prompt for our agent
system_prompt = """
You are a helpful personal assistant capable of performing local file actions and simple tasks for the user.

Your key capabilities:
1. Read, understand, and summarize files.
2. Create and write to files.
3. List directory contents and provide information on the files.
4. Summarize text content

When using tools:
- Always verify file paths before operations
- Be careful with system commands
- Provide clear explanations of what you're doing
- If a task cannot be completed, explain why and suggest alternatives

Always be helpful, concise, and focus on addressing the user's needs efficiently.
"""

model_id = (
    "llama3.2:1b"  # You can change this to any model you have pulled with Ollama.
)

# %% [markdown]
# #### Ollamaモデルの設定
# Ollamaサービスが http://localhost:11434 で実行されており、`model_id` が上記で印刷されたOllamaモデルのリストにあることを確認してください。

# %%
ollama_model = OllamaModel(
    model_id=model_id,
    host="http://localhost:11434",
    params={
        "max_tokens": 4096,  # Adjust based on your model's capabilities
        "temperature": 0.7,  # Lower for more deterministic responses, higher for more creative
        "top_p": 0.9,  # Nucleus sampling parameter
        "stream": True,  # Enable streaming responses
    },
)

# Create the agent
local_agent = Agent(
    system_prompt=system_prompt,
    model=ollama_model,
    tools=[file_read, file_write, list_directory],
)

# %% [markdown]
# ## エージェントのテスト
#
# いくつかのサンプルタスクでエージェントをテストしてみましょう。

# %%
local_agent(
    "Read the file in the path `sample_file/Amazon-com-Inc-2023-Shareholder-Letter.pdf` and summarize it in 5 bullet points."
)

# %%
# Example 2: List files in the current directory
response = local_agent("Show me the files in the current directory")

# %%
# Example 3: Create a sample file
response = local_agent(
    "Create a file called 'sample.txt' with the content 'This is a test file created by my Ollama agent.'"
)

# %%
# Example 4: create a readme file after reading and understanding multiple files
response = local_agent("Create a readme.md for the current directory")

# %% [markdown]
# ## 結論
#
# このノートブックでは、StandsとOllamaを使用してローカルパーソナルエージェントを作成しました。エージェントはファイル操作（読み取り、書き込み、追加）を行い、テキストを要約/分析できます。
#
# これは、OllamaでAIモデルをローカルに実行する力と、strandsのツールシステムの柔軟性を組み合わせたものです。ニーズに基づいて、より多くのツールを追加したり、異なるOllamaモデルを使用したりして、このエージェントを拡張できます。
#
# ### 次のステップ（アイデア）
#
# - エージェントの能力にどのように影響するかを確認するために、異なるOllamaモデルを試す
# - ウェブ検索、メール送信、カレンダー統合などのより複雑なツールを追加
# - エージェントが過去の対話を記憶するためのメモリを実装
# - エージェントと対話するためのシンプルなUIを作成
