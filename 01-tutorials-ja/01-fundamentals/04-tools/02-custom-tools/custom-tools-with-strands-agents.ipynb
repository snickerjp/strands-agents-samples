# %% [markdown]
# # Strands Agentsにカスタムツールを追加する
#
# ## 概要
#
# この例では、Strands Agentsを使用してカスタムツールを作成するさまざまな方法をガイドします。ローカルのSQLiteデータベースに接続してデータタスクを実行するパーソナルアシスタントのユースケースを構築します。ボーナスとして、`BedrockModel`クラスの`thinking`フィールドを使用してClaude Sonnet 3.7の推論機能をガイドします。
#
# ## Agent Details
#
# <div style="float: left; margin-right: 20px;">
#
# |Feature             |Description                                        |
# |--------------------|---------------------------------------------------|
# |Native tools used   |current_time, calculator                           |
# |Custom tools created|create_appointment, list_appointments              |
# |Agent Structure     |Single agent architecture                          |
#
# </div>

# %% [markdown]
# ## アーキテクチャ
#
# <div style="text-align:left">
#     <img src="images/architecture.png" width="85%" />
# </div>
#
# ## 主な機能
#
# * **Single agent architecture**: この例では、組み込みツールとカスタムツールと対話する単一のエージェントを作成します
# * **Built-in tools**: Strands Agentのツールの使用方法を学びます
# * **Custom tools**: 独自のツールを作成する方法を学びます
# * **Bedrock Model as underlying LLM**: Amazon BedrockのAnthropic Claude 3.7を基盤LLMモデルとして使用

# %% [markdown]
# ## セットアップと前提条件
#
# ### 前提条件
#
# * Python 3.10+
#
# * AWS account
#
# * Amazon BedrockでAnthropic Claude 3.7を有効化、[guide](https://docs.aws.amazon.com/bedrock/latest/userguide/model-access.html)
#
# * Amazon Bedrock Knowledge Base、Amazon S3 bucket、Amazon DynamoDBを作成する権限を持つIAMロール
#
# Strands Agentの要件パッケージをインストールしましょう

# %%
# installing pre-requisites
# !pip install -r requirements.txt

# %% [markdown]
# ### 依存パッケージのインポート
#
# 依存パッケージをインポートしましょう

# %%
import json
import sqlite3
import uuid
from datetime import datetime

from strands import Agent, tool
from strands.models import BedrockModel

# %% [markdown]
# ## カスタムツールの定義
#
# 次に、ローカルのSQLiteデータベースと対話するためのカスタムツールを定義します：
#
# * **create_appointment**: ユニークID、日付、場所、タイトル、説明付きの新しいパーソナルアポイントメントを作成
#
# * **list_appointment**: 利用可能なすべてのアポイントメントをリスト
#
# * **update_appointments**: アポイントメントIDに基づいてアポイントメントを更新

# %% [markdown]
# ### エージェントと同じファイルでツールを定義
#
# Strands Agents SDKでツールを定義する方法は複数あります。最初の方法は、関数に`@tool`デコレータを追加し、ドキュメントを提供することです。この場合、Strands Agentsは関数ドキュメント、タイプ、アーギュメントを使用してエージェントにツールを提供します。この場合、エージェントと同じファイルでツールを定義することもできます

# %%
@tool
def create_appointment(date: str, location: str, title: str, description: str) -> str:
    """
    Create a new personal appointment in the database.

    Args:
        date (str): Date and time of the appointment (format: YYYY-MM-DD HH:MM).
        location (str): Location of the appointment.
        title (str): Title of the appointment.
        description (str): Description of the appointment.

    Returns:
        str: The ID of the newly created appointment.

    Raises:
        ValueError: If the date format is invalid.
    """
    # Validate date format
    try:
        datetime.strptime(date, "%Y-%m-%d %H:%M")
    except ValueError:
        raise ValueError("Date must be in format 'YYYY-MM-DD HH:MM'")

    # Generate a unique ID
    appointment_id = str(uuid.uuid4())

    conn = sqlite3.connect("appointments.db")
    cursor = conn.cursor()

    # Create the appointments table if it doesn't exist
    cursor.execute(
        """
    CREATE TABLE IF NOT EXISTS appointments (
        id TEXT PRIMARY KEY,
        date TEXT,
        location TEXT,
        title TEXT,
        description TEXT
    )
    """
    )

    cursor.execute(
        "INSERT INTO appointments (id, date, location, title, description) VALUES (?, ?, ?, ?, ?)",
        (appointment_id, date, location, title, description),
    )

    conn.commit()
    conn.close()
    return f"Appointment with id {appointment_id} created"

# %% [markdown]
# ### モジュールベースのアプローチでのツール定義
#
# ツールをスタンドアロンファイルとして定義し、エージェントにインポートすることもできます。この場合、デコレータアプローチを使用するか、TOOL_SPEC辞書を使用して関数を定義することもできます。フォーマットは、[Amazon Bedrock Converse API](https://docs.aws.amazon.com/bedrock/latest/userguide/tool-use-examples.html)で使用されるものと似ています。この場合、必要なパラメータと成功/エラー実行の戻りを定義する柔軟性が高く、TOOL_SPEC定義が機能します。

# %% [markdown]
# #### デコレータアプローチ
#
# スタンドアロンファイルでデコレータを使用してツールを定義する場合、プロセスはエージェントと同じファイルの場合と非常に似ていますが、後でツールをインポートする必要があります。

# %%
# %%writefile list_appointments.py
import json
import sqlite3
import os
from strands import tool

@tool
def list_appointments() -> str:
    """
    List all available appointments from the database.
    
    Returns:
        str: the appointments available 
    """
    # Check if database exists
    if not os.path.exists('appointments.db'):
        return "No appointment available"
    
    conn = sqlite3.connect('appointments.db')
    conn.row_factory = sqlite3.Row  # This enables column access by name
    cursor = conn.cursor()
    
    # Check if the appointments table exists
    try:
        cursor.execute("SELECT name FROM sqlite_master WHERE type='table' AND name='appointments'")
        if not cursor.fetchone():
            conn.close()
            return "No appointment available"
        
        cursor.execute("SELECT * FROM appointments ORDER BY date")
        rows = cursor.fetchall()
        
        # Convert rows to dictionaries
        appointments = []
        for row in rows:
            appointment = {
                'id': row['id'],
                'date': row['date'],
                'location': row['location'],
                'title': row['title'],
                'description': row['description']
            }
            appointments.append(appointment)
        
        conn.close()
        return json.dumps(appointments)
    
    except sqlite3.Error:
        conn.close()
        return []

# %% [markdown]
# #### TOOL_SPECアプローチ
#
# 代替として、ツールを定義する際にTOOL_SPECアプローチを使用できます

# %%
# %%writefile update_appointment.py
import sqlite3
from datetime import datetime
import os
from strands.types.tools import ToolResult, ToolUse
from typing import Any

TOOL_SPEC = {
    "name": "update_appointment",
    "description": "Update an appointment based on the appointment ID.",
    "inputSchema": {
        "json": {
            "type": "object",
            "properties": {
                "appointment_id": {
                    "type": "string",
                    "description": "The appointment id."
                },
                "date": {
                    "type": "string",
                    "description": "Date and time of the appointment (format: YYYY-MM-DD HH:MM)."
                },
                "location": {
                    "type": "string",
                    "description": "Location of the appointment."
                },
                "title": {
                    "type": "string",
                    "description": "Title of the appointment."
                },
                "description": {
                    "type": "string",
                    "description": "Description of the appointment."
                }
            },
            "required": ["appointment_id"]
        }
    }
}
# Function name must match tool name
def update_appointment(tool: ToolUse, **kwargs: Any) -> ToolResult:
    tool_use_id = tool["toolUseId"]
    appointment_id = tool["input"]["appointment_id"]
    if "date" in tool["input"]:
        date = tool["input"]["date"]
    else:
        date = None
    if "location" in tool["input"]:
        location = tool["input"]["location"]
    else:
        location = None
    if "title" in tool["input"]:
        title = tool["input"]["title"]
    else:
        title = None
    if "description" in tool["input"]:
        description = tool["input"]["description"]
    else:
        description = None
        
    # Check if database exists
    if not os.path.exists('appointments.db'): 
        return {
            "toolUseId": tool_use_id,
            "status": "error",
            "content": [{"text": f"Appointment {appointment_id} does not exist"}]
        } 
    
    # Check if appointment exists
    conn = sqlite3.connect('appointments.db')
    cursor = conn.cursor()
    
    # Check if the appointments table exists
    try:
        cursor.execute("SELECT name FROM sqlite_master WHERE type='table' AND name='appointments'")
        if not cursor.fetchone():
            conn.close()
            return {
                "toolUseId": tool_use_id,
                "status": "error",
                "content": [{"text": f"Appointments table does not exist"}]
            }
        
        cursor.execute("SELECT * FROM appointments WHERE id = ?", (appointment_id,))
        appointment = cursor.fetchone()
        
        if not appointment:
            conn.close()
            return {
                "toolUseId": tool_use_id,
                "status": "error",
                "content": [{"text": f"Appointment {appointment_id} does not exist"}]
            }
        
        # Validate date format if provided
        if date:
            try:
                datetime.strptime(date, '%Y-%m-%d %H:%M')
            except ValueError:
                conn.close()
                return {
                    "toolUseId": tool_use_id,
                    "status": "error",
                    "content": [{"text": "Date must be in format 'YYYY-MM-DD HH:MM'"}]
                }
        
        # Build update query
        update_fields = []
        params = []
        
        if date:
            update_fields.append("date = ?")
            params.append(date)
        
        if location:
            update_fields.append("location = ?")
            params.append(location)
        
        if title:
            update_fields.append("title = ?")
            params.append(title)
        
        if description:
            update_fields.append("description = ?")
            params.append(description)
        
        # If no fields to update
        if not update_fields:
            conn.close()
            return {
                "toolUseId": tool_use_id,
                "status": "success",
                "content": [{"text": "No need to update your appointment, you are all set!"}]
            }
        
        # Complete the query
        query = f"UPDATE appointments SET {', '.join(update_fields)} WHERE id = ?"
        params.append(appointment_id)
        
        cursor.execute(query, params)
        conn.commit()
        conn.close()
        
        return {
            "toolUseId": tool_use_id,
            "status": "success",
            "content": [{"text": f"Appointment {appointment_id} updated with success"}]
        }
    
    except sqlite3.Error as e:
        conn.close()
        return {
            "toolUseId": tool_use_id,
            "status": "error",
            "content": [{"text": str(e)}]
        }

# %% [markdown]
# `list_appointments`と`update_appointment`をツールとしてインポートしましょう

# %%
import list_appointments
import update_appointment

# %% [markdown]
# ## エージェントの作成
#
# カスタムツールを作成したので、最初のエージェントを定義しましょう。そのためには、エージェントが何をすべきか、何をすべきでないかを定義するシステムプロンプトを作成する必要があります。次に、エージェントの基盤LLMモデルを定義し、組み込みツールとカスタムツールを提供します。
#
# #### エージェントシステムプロンプトの設定
#
# システムプロンプトでエージェントの指示を定義します

# %%
system_prompt = """You are a helpful personal assistant that specializes in managing my appointments and calendar. 
You have access to appointment management tools, a calculator, and can check the current time to help me organize my schedule effectively. 
Always provide the appointment id so that I can update it if required"""

# %% [markdown]
# #### エージェントの基盤LLMモデルの定義
#
# 次に、エージェントの基盤モデルを定義しましょう。Strands AgentsはAmazon Bedrockモデルとネイティブに統合し、モデルがどのように呼び出されるかを設定する能力を提供します。以下では、`BedrockModel`プロバイダーのシンプルな初期化を見ることができ、オプションの設定の一部がコメントアウトされています。設定オプションとデフォルト値については、[Strands Agents Bedrock Model Provider documentation](https://strandsagents.com/0.1.x/user-guide/concepts/model-providers/amazon-bedrock/)で詳しく学ぶことができます。この例では、Bedrockの`Anthropic Claude 3.7 Sonnet`モデルを使用します。

# %%
model = BedrockModel(
    model_id="us.anthropic.claude-3-7-sonnet-20250219-v1:0",
    # region_name="us-east-1",
    # boto_client_config=Config(
    #    read_timeout=900,
    #    connect_timeout=900,
    #    retries=dict(max_attempts=3, mode="adaptive"),
    # ),
    # temperature=0.9,
    # max_tokens=2048,
)

# %% [markdown]
# #### 組み込みツールのインポート
#
# エージェントを構築する次のステップは、Strands Agentsの組み込みツールをインポートすることです。Strands Agentsは、オプションのパッケージ`strands-tools`で一般的に使用される組み込みツールのセットを提供します。このリポジトリでRAG、メモリ、ファイル操作、コード解釈などのツールが利用可能です。この例では、エージェントに現在の時刻の情報を提供する`current_time`ツールと、いくつかの数学を行う`calculator`ツールを使用します

# %%
from strands_tools import calculator, current_time

# %% [markdown]
# #### エージェントの定義
#
# 必要な情報がすべて揃ったので、エージェントを定義しましょう

# %%
agent = Agent(
    model=model,
    system_prompt=system_prompt,
    tools=[
        current_time,
        calculator,
        create_appointment,
        list_appointments,
        update_appointment,
    ],
)

# %% [markdown]
# ## エージェントの呼び出し
#
# レストランエージェントを挨拶で呼び出し、その結果を分析しましょう

# %%
results = agent("How much is 2+2?")

# %% [markdown]
# #### エージェントの結果の分析
#
# 素晴らしい！初めてエージェントを呼び出しました！resultsオブジェクトを探索しましょう。最初に見られるのは、エージェントのオブジェクトで交換されるメッセージです

# %%
agent.messages

# %% [markdown]
# 次に、result `metrics` を分析することで、最後のクエリに対するエージェントの使用状況を確認できます

# %%
results.metrics

# %% [markdown]
# #### フォローアップ質問でエージェントを呼び出し
#
# OK、明日アポイントメントを作成しましょう

# %%
results = agent(
    "Book 'Agent fun' for tomorrow 3pm in NYC. This meeting will discuss all the fun things that an agent can do"
)

# %% [markdown]
# #### アポイントメントの更新
#
# このアポイントメントを更新しましょう

# %%
results = agent("Oh no! My bad, 'Agent fun' is actually happening in DC")

# %% [markdown]
# #### エージェントの結果の分析
#
# エージェントのメッセージと結果メトリクスをもう一度見てみましょう

# %%
agent.messages

# %%
results.metrics

# %% [markdown]
# #### メッセージからのツール使用状況の確認
#
# メッセージ辞書内のツール使用状況を深く掘り下げましょう。後でエージェントの動作を観察し評価する方法を示しますが、これはその最初のステップです

# %%
for m in agent.messages:
    for content in m["content"]:
        if "toolUse" in content:
            print("Tool Use:")
            tool_use = content["toolUse"]
            print("\tToolUseId: ", tool_use["toolUseId"])
            print("\tname: ", tool_use["name"])
            print("\tinput: ", tool_use["input"])
        if "toolResult" in content:
            print("Tool Result:")
            tool_result = m["content"][0]["toolResult"]
            print("\tToolUseId: ", tool_result["toolUseId"])
            print("\tStatus: ", tool_result["status"])
            print("\tContent: ", tool_result["content"])
            print("=======================")

# %% [markdown]
# ### アクションが正しく実行されたことを検証
#
# データベースを確認して、操作が正しく行われたことを確認しましょう。`Agent`クラスには、`agent.tool.<tool_name>(<tool_params>)`を呼び出すことで、エージェントが初期化されたツールを直接呼び出す機能があります。直接ツール呼び出しは、エージェントがツール自体を呼び出す必要なく、ツールから情報をエージェントに与えるのに最適です。この直接ツール呼び出しを使用して、現在のアポイントメントをリストできます：

# %%
list_appointments_result = agent.tool.list_appointments()
print(json.dumps(list_appointments_result, indent=2))

# %% [markdown]
# ツール実行の結果がToolResult形式であることがわかります。これには`toolUseId`、実行`status`、応答の`content`が含まれます。ツールの結果をより良く視覚化するには次のようにします：

# %%
list_appointments_result_text_content = list_appointments_result["content"][0]["text"]
print(json.dumps(json.loads(list_appointments_result_text_content), indent=2))

# %% [markdown]
# 最後に、直接ツール呼び出しを使用してツールを実行する場合、エージェントはこれらの実行をメッセージ履歴に記録します。デフォルトで有効ですが、`Agent`クラスの`record_direct_tool_call`ブールフラグ属性で無効にできます。

# %%
current_time_result = agent.tool.current_time()
print("Current Time direct tool call result:")
print(current_time_result)
current_time_direct_tool_messages = agent.messages[-4:]
print("Current Time direct tool call messages:")
print(current_time_direct_tool_messages)

agent.record_direct_tool_call = False # Set the record_direct_tool_call to False
agent.tool.list_appointments()
after_disable_record_messages = agent.messages[-4:]
print("After disabling record direct tool call messages, history should not have changed:")
print(current_time_direct_tool_messages == after_disable_record_messages)

# %% [markdown]
# ## 拡張: 拡張思考
#
# 拡張思考は、サポートされたClaudeファミリーモデルが複雑なタスクに対して強化された推論機能を活用できるようにし、最終回答を提供する前に透明なステップバイステップの思考プロセスを提供します。思考を有効にするには、Bedrock ModelProviderを設定する際に以下の設定を含めます。詳しくは[AWS's documentation on Extended Thinking](https://docs.aws.amazon.com/bedrock/latest/userguide/claude-messages-extended-thinking.html)で学ぶことができます。

# %%
thinking_model = BedrockModel(
    model_id="us.anthropic.claude-3-7-sonnet-20250219-v1:0",
    additional_request_fields={
        "thinking": {
            "type": "enabled",
            "budget_tokens": 2048,
        }
    },
)

# %% [markdown]
# `thinking_model`を定義した後、新しい`thinking_agent`を作成して呼び出すことができます：

# %%
thinking_system_prompt = """You are a helpful personal assistant that specializes in managing my appointments and calendar. 
You have access to appointment management tools, a calculator, and can check the current time to help me organize my schedule effectively. 
You think through your problem, step by step, to come up with an answer.
Always provide the appointment id so that I can update it if required"""

thinking_agent = Agent(
    model=thinking_model,
    system_prompt=thinking_system_prompt,
    tools=[
        current_time,
        calculator,
        create_appointment,
        list_appointments,
        update_appointment,
    ],
)

thinking_result = thinking_agent("I want to add a new appointment for tomorrow at 2pm")

# %% [markdown]
# エージェントのメッセージを出力することで、拡張思考機能をより良く分析できます。拡張思考は、エージェントの応答で`reasoningContent`ブロックとして表されます。

# %%
thinking_agent.messages

# %% [markdown]
# ## 素晴らしい仕事！
#
# 次のモジュールでお会いしましょう。 :)
