# %% [markdown]
# # Strands Agentsセッション間でメモリを永続化する
#
# この例では、Strands Agentsで異なるセッション間でメモリを永続化する方法を学びます。
#
# `duckduckgo`検索APIを使用したウェブ検索を行うエージェントのユースケースを使用します。
#
# このノートブックでは：
# - メモリを活用したStrandsエージェントの機能を探索します。
# - メモリの保存、取得、リスト方法を学びます。
# - エージェント経由でウェブ検索を実行する方法を理解します。
# - インタラクティブループでエージェントと対話します。
#
#
# ### 使用例
#
# メモリの保存：
# ```
# Remember that I prefer tea over coffee
# ```
#
# メモリの取得：
# ```
# What do I prefer to drink?
# ```
#
# すべてのメモリのリスト：
# ```
# Show me everything you remember about me
# ```
#
# ### メモリ使用のヒント
#
# - エージェントに情報を記憶するよう明示的に依頼する
# - 関連するメモリを取得するために具体的なクエリを使用する
# - メモリの永続化により、より自然で文脈のある会話が可能になる

# %% [markdown]
# ## セットアップと前提条件
#
# ### 前提条件
# * Python 3.10+
# * AWSアカウントと環境で設定されたAWSクレデンシャル
# * Amazon BedrockでAnthropic Claude 3.7を有効化
# * Amazon Bedrock Knowledge Base、Amazon S3バケット、Amazon DynamoDBを作成する権限を持つIAMロール
#
# Strands Agentの要件パッケージをインストールしましょう

# %%
# Install the required packages
# !pip install -r requirements.txt

# %%
# Import Required Libraries
import os
from strands import Agent, tool
from strands.models import bedrock
from strands_tools import mem0_memory

from ddgs import DDGS
from ddgs.exceptions import DDGSException, RatelimitException

bedrock.DEFAULT_BEDROCK_MODEL_ID = "us.anthropic.claude-3-7-sonnet-20250219-v1:0" #Optional: Set a default model for Bedrock

# %% [markdown]
# ## Mem0設定
#
# ### メモリバックエンドオプション
#
# Mem0 Memory Toolは3つの異なるバックエンド設定をサポートします：
#
# 1. **[OpenSearch](https://aws.amazon.com/opensearch-service/features/serverless/)** (AWS環境で推奨)：
#    - AWSクレデンシャルとOpenSearch設定が必要
#    - `OPENSEARCH_HOST`を設定し、オプションで`AWS_REGION` (デフォルトはus-west-2)
#
# 2. **[FAISS]((https://faiss.ai/index.html))** (ローカル開発のデフォルト)：
#    - FAISSをローカルベクトルストアバックエンドとして使用
#    - ローカルベクトルストレージにfaiss-cpuパッケージが必要
#    - 追加設定不要
#
# 3. **Mem0 Platform**：
#    - [Mem0 Platform API](https://docs.mem0.ai/platform/quickstart)を使用してメモリ管理
#    - Mem0 APIキー：環境変数`MEM0_API_KEY`が必要
#
#
# ### 環境設定
#
# | 環境変数 | 説明 | デフォルト | 必須対象 |
# |---------------------|-------------|----------|--------------|
# | OPENSEARCH_HOST | OpenSearch Serverless Host URL | None | OpenSearch |
# | AWS_REGION | OpenSearchのAWSリージョン | us-west-2 | OpenSearch |
# | MEM0_API_KEY | Mem0 Platform APIキー | None | Mem0 Platform |
# | DEV | 開発モードを有効化 | false | すべてのモード |
#
#
# このラボの範囲では、メモリ管理のバックエンドとして2つのオプションを使用できます：
# ### オプション1. [Opensearch Serverless](https://aws.amazon.com/opensearch-service/features/serverless/)
#
# AOSSのセットアップアーキテクチャは以下のようになります：
#
# <div style="text-align:left">
#     <img src="images/arch_AOSS.png" width="65%" />
# </div>

# %%
# You can manually define your Opensearch Host 
#os.environ["OPENSEARCH_HOST"] = "<your-opensearch-host>.<region>.aoss.amazonaws.com"

# %%
# OR - Run the script to Create Opensearch Serverless resource in your AWS Account
# !bash prereqs/deploy_OSS.sh

# %%
# Option 1: Opensearch Serverless
from dotenv import load_dotenv
load_dotenv() # take Opensearch environment variables

# %% [markdown]
# ### オプション2 [Mem0 Platform](https://docs.mem0.ai/platform)：
#
# #### [注意]: Opensearch Serverlessオプションをすでにデプロイしている場合は不要です。
#
# 代替として、[ここ](https://docs.mem0.ai/platform/quickstart#2-api-key-setup)の手順に従ってMem0 APIキーを作成し、環境変数**MEM0_API_KEY**として追加できます。
# Mem0 Platformのセットアップアーキテクチャは以下のようになります：
#
# <div style="text-align:left">
#     <img src="images/arch_mem0.png" width="65%" />
# </div>
#
#
# エージェントの機能を有効にするために、AWSクレデンシャルとOpenSearch / Mem0 Platformの環境変数を設定する必要があります。これらの変数はメモリの保存と取得に使用されます。

# %%
# Option 2: Mem0 API key

#os.environ["MEM0_API_KEY"] = "<your-mem0-api-key>"

# %% [markdown]
# ## システムプロンプトの定義
#
# `SYSTEM_PROMPT`変数は、メモリエージェントの動作と機能を定義します。このプロンプトは、エージェントが保存されたメモリに基づいてパーソナライズされた応答を提供し、必要に応じてウェブ検索を実行するようガイドします。

# %%
# Define a focused system prompt for memory operations
SYSTEM_PROMPT = """You are a helpful personal assistant for a user. Your task is to assist the user by providing personalized responses based on their history. 

Capabilities:
- You can store information using the mem0_memory tool (action="store").
- You can retrieve relevant memories using the mem0_memory tool (action="retrieve").
- You can use duckduckgo_search to find information on the web.

Key Rules:
- Be conversational and natural in your responses.
- Always retrieve memories before responding to the user and use them to inform your response.
- Store any new user information and user preferences in mem0_memory.
- Only share relevant information.
- Politely indicate when you don't have the information.
"""

# %% [markdown]
# ## ウェブ検索ツールの定義
#
# [Duckduckgo Search API](https://github.com/deedy5/duckduckgo_search)関数を使用した`websearch`ツールにより、エージェントはウェブ検索を実行できます。この関数は例外を処理し、検索結果または適切なエラーメッセージを返します。

# %%
@tool
def websearch(
    keywords: str,
    region: str = "us-en",
    max_results: int | None = None,
) -> str:
    """Search the web to get updated information.
    Args:
        keywords (str): The search query keywords.
        region (str): The search region: wt-wt, us-en, uk-en, ru-ru, etc..
        max_results (int | None): The maximum number of results to return.
    Returns:
        List of dictionaries with search results.
    """
    try:
        results = DDGS().text(keywords, region=region, max_results=max_results)
        return results if results else "No results found."
    except RatelimitException:
        return "RatelimitException: Please try again after a short delay."
    except DDGSException as d:
        return f"DuckDuckGoSearchException: {d}"
    except Exception as e:
        return f"Exception: {e}"

# %% [markdown]
# ## メモリエージェントの作成
#
# 定義したツールとシステムプロンプトを使用して、メモリに焦点を当てたエージェントを初期化します。Strandsエージェントは以下のことができます：
# 1. 文脈に基づいてメモリを保存・取得します。メモリを使用して、よりパーソナライズされた文脈のあるAIインタラクションを作成します。
# 2. DuckDuckGoを使用してウェブ検索を実行し、更新された情報を提供します。

# %%
# Create an agent with memory, websearch tool
USER_ID = "new_user" # Replace with actual user ID

memory_agent = Agent(
    system_prompt=SYSTEM_PROMPT,
    model="us.anthropic.claude-3-7-sonnet-20250219-v1:0",  # Optional: Specify the model ID
    tools=[mem0_memory, websearch],
)

# %% [markdown]
# ## メモリ操作のデモンストレーション
#
# 以下の例は、メモリエージェントを使用してメモリを保存、取得、リストする方法を示します。
#
# - **store**: 後で取得するために重要な情報を保存
#   - ユーザーの好みを保存
#   - 重要な事実を記憶
#   - 会話の文脈を維持
#
# - **retrieve**: クエリに基づいて関連するメモリにアクセス
#   - 以前に保存された情報を検索
#   - ユーザーの履歴に基づいてパーソナライズされた応答を提供
#
# - **list**: 保存されたすべてのメモリを表示
#   - 保存された情報を確認
#   - 保存されたメモリを監査

# %%
# Store initial memories to demonstrate retrieval
memory_agent.tool.mem0_memory(
    action="store", content=f"The user's name is {USER_ID}.", user_id=USER_ID
)
memory_agent.tool.mem0_memory(
    action="store", 
    content="I like to drink tea more than coffee.", 
    user_id=USER_ID
)

# %%
# Retrieve memories
retrieved_memories = memory_agent.tool.mem0_memory(
    action="retrieve", query="What is the user's name?", user_id=USER_ID
)
print("Retrieved Memories:", retrieved_memories)

# %%
# Retrieve memories about preferences
memory_agent.tool.mem0_memory(
    action="retrieve",
    query="What are the my drink preferences?",
    user_id=USER_ID
)

# %%
# Ask the agent a question
response = memory_agent("What are the events happening in the New York today?")
print(response)

# %%
# List all stored memories
print("All Stored Memories:")
all_memories = memory_agent.tool.mem0_memory(
    action="list", user_id=USER_ID
)

# %% [markdown]
# ## インタラクティブなエージェントの使用
#
# 最後に、ユーザーがメモリエージェントと対話するためのインタラクティブループを提供します。ユーザーは新しいメモリを保存、既存のメモリを取得、または保存されたすべてのメモリをリストできます。
#
# インタラクティブな使用をテストするには：
# 1. 要件をインストール：`pip install -r requirements.txt`
# 1. Pythonファイル`personal_agent_with_memory.py`を実行します。

# %% [markdown]
# ## 結論
#
# このノートブックでは、Strandsフレームワークを使用してメモリ機能を備えたパーソナルエージェントを作成する方法を示します。エージェントは以下のことができます：
#
# 1. ユーザーに関する情報を保存
# 2. 文脈に基づいて関連するメモリを取得
# 3. 追加情報をウェブ検索
# 4. パーソナライズされた応答を提供
#
# これらの機能を組み合わせることで、エージェントは会話間で文脈を維持し、時間とともによりパーソナライズされた支援を提供できます。

# %% [markdown]
# ### クリーンアップ
#
# Opensearch Serverlessリソースをクリーンアップするためにこのbashスクリプトを実行します。"MEM0_PLATFORM_API"を使用した場合は実行する必要はありません。

# %%
# !sh prereqs/cleanup_OSS.sh
